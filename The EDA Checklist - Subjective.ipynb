# %%
import pandas as pd
import numpy as np

np.random.seed(42)

n = 200

data = {
    "order_id": range(1001, 1001 + n),
    "city": np.random.choice(["Mumbai", "Delhi", "Bangalore", "Chennai"], size=n),
    "category": np.random.choice(["Electronics", "Clothing", "Groceries", "Furniture"], size=n),
    "order_value": np.random.randint(200, 5000, size=n).astype(float),
    "delivery_days": np.random.randint(1, 15, size=n).astype(float),
    "rating": np.random.choice([1, 2, 3, 4, 5, None], size=n)
}

missing_indices_order = np.random.choice(n, size=15, replace=False)
missing_indices_delivery = np.random.choice(n, size=10, replace=False)
data["order_value"][missing_indices_order] = np.nan
data["delivery_days"][missing_indices_delivery] = np.nan

data["order_value"][5] = 95000
data["order_value"][88] = 87000

df = pd.DataFrame(data)
print(df.shape)
df.head()

'''
Task 1- Inspect & Handle Missing Values

1. Print the shape of the DataFrame (number of rows and columns).
2. Display the data types of all columns.
3. Count the number of missing values in each column.
4. Calculate the percentage of missing values for each column, rounded to 2 decimal places.

Hint: Percentage = (missing count / total rows) * 100



'''
# Out:
# (200, 6)
# '\nTask 1- Inspect & Handle Missing Values\n\n1. Print the shape of the DataFrame (number of rows and columns).\n2. Display the data types of all columns.\n3. Count the number of missing values in each column.\n4. Calculate the percentage of missing values for each column, rounded to 2 decimal places.\n\nHint: Percentage = (missing count / total rows) * 100\n\n\n\n'

# %% [markdown]
# Task 1- Inspect & Handle Missing Values
#
# 1. Print the shape of the DataFrame (number of rows and columns).
# 2. Display the data types of all columns.
# 3. Count the number of missing values in each column.
# 4. Calculate the percentage of missing values for each column, rounded to 2 decimal places.
#
# Hint: Percentage = (missing count / total rows) * 100

# %% [markdown]
# Task 1- Inspect & Handle Missing Values

# %%
# 1. Print the shape of the DataFrame (number of rows and columns).
df = pd.DataFrame(data)
print(df.shape)

# 2. Display the data types of all columns.
df.dtypes
# 3. Count the number of missing values in each column.
df.isna().sum()
# Out:
# (200, 6)
# order_id          0
# city              0
# category          0
# order_value      14
# delivery_days    10
# rating           32
# dtype: int64

# %%
# 4. Calculate the percentage of missing values for each column, rounded to 2 decimal places.
missing_count=df.isna().sum()

total_rows=len(df)
Percentage = (missing_count / total_rows) * 100
Percentage
# Out:
# order_id          0.0
# city              0.0
# category          0.0
# order_value       7.0
# delivery_days     5.0
# rating           16.0
# dtype: float64

# %%
len(df)
# Out:
# 200

# %% [markdown]
# Task 3 - Correlation Analysis
#
# 1. Compute the correlation matrix for all numerical columns using df. corr().
# 2. Plot a heatmap of the correlation matrix with annotation values visible inside each cell.
# 3. In a markdown cell, write one observation from the heatmap - identify any two columns that appear to have a
# notable positive or negative relationship.

# %%
df.dtypes
# Out:
# order_id           int64
# city              object
# category          object
# order_value      float64
# delivery_days    float64
# rating            object
# dtype: object

# %% [markdown]
# Task 2 - Summarize & Visualize
#
# 1. Use df.describe() to generate a summary of all numerical columns. In a markdown cell below the output, write two observations from the summary (for example: which
# column has the highest mean, or which column shows a large gap between its max and 75th percentile).
# 2. Plot a histogram for the order_value column to visualize its distribution.
# 3. Plot a box plot for the delivery_days column to inspect for outliers.
#
# Make sure every plot has a title and axis labels.

# %%
'''Task 2 - Summarize & Visualize

1. Use df.describe() to generate a summary of all numerical columns. In a markdown cell below the output, write two observations from the summary 
(for example: which column has the highest mean, or which column shows a large gap between its max and 75th percentile).
2. Plot a histogram for the order_value column to visualize its distribution.
3. Plot a box plot for the delivery_days column to inspect for outliers.

Make sure every plot has a title and axis labels.
'''
# Out:
# 'Task 2 - Summarize & Visualize\n\n1. Use df.describe() to generate a summary of all numerical columns. In a markdown cell below the output, write two observations from the summary \n(for example: which column has the highest mean, or which column shows a large gap between its max and 75th percentile).\n2. Plot a histogram for the order_value column to visualize its distribution.\n3. Plot a box plot for the delivery_days column to inspect for outliers.\n\nMake sure every plot has a title and axis labels.\n'

# %%
df.describe()
# Out:
#           order_id   order_value  delivery_days
# count   200.000000    186.000000     190.000000
# mean   1100.500000   3707.134409       7.810526
# std      57.879185   9238.438378       4.075465
# min    1001.000000    204.000000       1.000000
# 25%    1050.750000   1512.000000       4.000000
# 50%    1100.500000   2934.000000       8.000000
# 75%    1150.250000   3987.500000      12.000000
# max    1200.000000  95000.000000      14.000000

# %%
import plotly.express as px

fig = px.histogram(df, x='order_value', title='Distribution of Order Value', labels={'order_value': 'Order Value'})
fig.show()

# %%
import plotly.express as px
fig=px.box(df,x='delivery_days', title='Box Plot for the delivery_days',labels={'delivery_days': 'Delivery Days'})
fig.show()

# %% [markdown]
# Task 3 — Correlation Analysis
# Compute the correlation matrix for all numerical columns using df.corr().
# Plot a heatmap of the correlation matrix with annotation values visible inside each cell.
# In a markdown cell, write one observation from the heatmap — identify any two columns that appear to have a notable positive or negative relationship.

# %%
df.corr(numeric_only=True)
# Out:
#                order_id  order_value  delivery_days
# order_id       1.000000    -0.095503       0.004858
# order_value   -0.095503     1.000000       0.141660
# delivery_days  0.004858     0.141660       1.000000

# %%
import plotly.express as px

corr_matrix = df.corr(numeric_only=True)

fig = px.imshow(corr_matrix, text_auto=True, title='Correlation Heatmap')
fig.show()
